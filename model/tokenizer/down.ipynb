# %%
from transformers import AutoTokenizer

tok = AutoTokenizer.from_pretrained("bert-base-chinese")
tok.save_pretrained("./tokenizer_bert_chinese")
# Out:
# '[Errno 99] Cannot assign requested address' thrown while requesting HEAD https://huggingface.co/bert-base-chinese/resolve/main/config.json
# Retrying in 1s [Retry 1/5].
# '[Errno 99] Cannot assign requested address' thrown while requesting HEAD https://huggingface.co/bert-base-chinese/resolve/main/config.json
# Retrying in 1s [Retry 1/5].
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File ~/miniconda3/lib/python3.12/site-packages/transformers/configuration_utils.py:735, in PreTrainedConfig._get_config_dict(cls, pretrained_model_name_or_path, **kwargs)
#     733 try:
#     734     # Load from local folder or from cache or download from model Hub and cache
# --> 735     resolved_config_file = cached_file(
#     736         pretrained_model_name_or_path,
#     737         configuration_file,
#     738         cache_dir=cache_dir,
# ...

# %%
tok = AutoTokenizer.from_pretrained("./tokenizer_bert_chinese")

print(len(tok))
print(tok.vocab_size)
print(tok.pad_token_id)
print(tok.unk_token_id)
print(tok.cls_token_id)
print(tok.sep_token_id)
